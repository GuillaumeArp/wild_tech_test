# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import requests
from sqlalchemy import create_engine, text
import os
from dotenv import load_dotenv

load_dotenv()

AWSDBHOST = os.getenv("AWSDBHOST")
AWSDBUSER = os.getenv("AWSDBUSER")
AWSDBPASS = os.getenv("AWSDBPASS")
AWSDBNAME = os.getenv("AWSDBNAME")

# %% [markdown]
# ## Extraction

# %%
engine = create_engine(f"mysql+pymysql://{AWSDBUSER}:{AWSDBPASS}@{AWSDBHOST}/{AWSDBNAME}", echo=True)

# %%
query = text("SELECT * FROM address ")
df_address = pd.read_sql(query, engine)

df_address
# Out:
# 2022-05-18 22:58:01,027 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2022-05-18 22:58:01,028 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 22:58:01,052 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2022-05-18 22:58:01,053 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 22:58:01,063 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2022-05-18 22:58:01,064 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 22:58:01,104 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2022-05-18 22:58:01,104 INFO sqlalchemy.engine.Engine [generated in 0.00054s] {'table_schema': 'dataengineer', 'table_name': 'SELECT * FROM address '}
# 2022-05-18 22:58:01,127 INFO sqlalchemy.engine.Engine SELECT * FROM address
# 2022-05-18 22:58:01,127 INFO sqlalchemy.engine.Engine [generated in 0.00052s] {}
#      address_id                  address                  city postal_code
# 0             1     318 CHE DE ROUMAGOUA             LA CIOTAT       13600
# 1             2         19 RUE DES DAMES         SAINTE SAVINE       10300
# 2             3  22 RUE AMIRAL GUEPRATTE            LE CONQUET       29217
# 3             4          6 BD DES ETINES             LE COTEAU       42120
# 4             5      35 AV DU 159EME RIA              BRIANCON        5100
# ..          ...                      ...                   ...         ...
# 557         601              20 RUE COLI             MONTREUIL       93100
# 558         602         6 AV JEAN JAURES                 FEURS       42110
# 559         603     1 RUE HENRI RENAUDIN  CHARLEVILLE-MEZIERES        8000
# 560         604            2 RUE DE LYON      EPINAY SUR SEINE       93800
# 561         605        4 RUE DENIS PAPIN                 BLAIN       44130
#
# [562 rows x 4 columns]

# %% [markdown]
# ## Transformation

# %%
df_address['postal_code'] = df_address['postal_code'].astype(str).apply(lambda x: x.zfill(5))
df_address['city'] = df_address['city'].apply(lambda x: re.sub('\s\d+EME', '', x)).apply(lambda x: re.sub('\s\d+', '', x))
df_address
# Out:
#      address_id                  address                  city postal_code
# 0             1     318 CHE DE ROUMAGOUA             LA CIOTAT       13600
# 1             2         19 RUE DES DAMES         SAINTE SAVINE       10300
# 2             3  22 RUE AMIRAL GUEPRATTE            LE CONQUET       29217
# 3             4          6 BD DES ETINES             LE COTEAU       42120
# 4             5      35 AV DU 159EME RIA              BRIANCON       05100
# ..          ...                      ...                   ...         ...
# 557         601              20 RUE COLI             MONTREUIL       93100
# 558         602         6 AV JEAN JAURES                 FEURS       42110
# 559         603     1 RUE HENRI RENAUDIN  CHARLEVILLE-MEZIERES       08000
# 560         604            2 RUE DE LYON      EPINAY SUR SEINE       93800
# 561         605        4 RUE DENIS PAPIN                 BLAIN       44130
#
# [562 rows x 4 columns]

# %%
lat_dict = {}
lon_dict = {}

for i in df_address.itertuples():
    index_num = i.address_id
    street = i.address
    city = i.city
    postalcode = i.postal_code
    try:
        r = requests.get(f"https://nominatim.openstreetmap.org/search?city={city}&street={street}&postalcode={postalcode}&format=json").json()
        lat_dict[index_num] = (r[0]['lat'])        
        lon_dict[index_num] = (r[0]['lon'])
    except IndexError:
        try:
            r = requests.get(f"https://nominatim.openstreetmap.org/search?city={city}&postalcode={postalcode}&format=json").json()
            lat_dict[index_num] = (r[0]['lat'])        
            lon_dict[index_num] = (r[0]['lon'])
        except:
            r = requests.get(f"https://nominatim.openstreetmap.org/search?postalcode={postalcode}&format=json").json()
            lat_dict[index_num] = (r[0]['lat'])        
            lon_dict[index_num] = (r[0]['lon'])

df_address['latitude'] = df_address['address_id'].map(lat_dict).astype(float)
df_address['longitude'] = df_address['address_id'].map(lon_dict).astype(float)

df_address
# Out:
#      address_id                  address                  city postal_code  \
# 0             1     318 CHE DE ROUMAGOUA             LA CIOTAT       13600
# 1             2         19 RUE DES DAMES         SAINTE SAVINE       10300
# 2             3  22 RUE AMIRAL GUEPRATTE            LE CONQUET       29217
# 3             4          6 BD DES ETINES             LE COTEAU       42120
# 4             5      35 AV DU 159EME RIA              BRIANCON       05100
# ..          ...                      ...                   ...         ...
# 557         601              20 RUE COLI             MONTREUIL       93100
# 558         602         6 AV JEAN JAURES                 FEURS       42110
# 559         603     1 RUE HENRI RENAUDIN  CHARLEVILLE-MEZIERES       08000
# 560         604            2 RUE DE LYON      EPINAY SUR SEINE       93800
# 561         605        4 RUE DENIS PAPIN                 BLAIN       44130
#
#       latitude  longitude
# 0    43.200998   5.605799
# 1    48.290905   4.045789
# 2    48.361340  -4.766800
# 3    46.021659   4.092120
# 4    44.898404   6.643631
# ..         ...        ...
# 557  48.868459   2.468415
# 558  45.743563   4.226839
# 559  49.773546   4.708829
# 560  48.953836   2.292919
# 561  47.482766  -1.747235
#
# [562 rows x 6 columns]

# %% [markdown]
# ## Loading

# %%
query = "ALTER TABLE address ADD latitude FLOAT, ADD longitude FLOAT;"
with engine.connect() as con:
    con.execute(query)
# Out:
# 2022-05-18 23:03:17,790 INFO sqlalchemy.engine.Engine ALTER TABLE address ADD latitude FLOAT, ADD longitude FLOAT;
# 2022-05-18 23:03:17,793 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:17,833 INFO sqlalchemy.engine.Engine COMMIT

# %%
for i in lat_dict.keys():
    query = f"UPDATE address SET latitude = {lat_dict.get(i)}, longitude = {lon_dict.get(i)} WHERE address_id = {i}"
    with engine.connect() as con:
        con.execute(query)
# Out:
# 2022-05-18 23:03:17,885 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 43.2009979, longitude = 5.6057988 WHERE address_id = 1
# 2022-05-18 23:03:17,886 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:17,898 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:17,921 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 48.2909051, longitude = 4.0457894 WHERE address_id = 2
# 2022-05-18 23:03:17,921 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:17,942 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:17,970 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 48.3613399, longitude = -4.7667997 WHERE address_id = 3
# 2022-05-18 23:03:17,971 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:17,982 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:18,010 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 46.021659, longitude = 4.0921204 WHERE address_id = 4
# 2022-05-18 23:03:18,010 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:18,021 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:18,046 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 44.8984037, longitude = 6.6436313 WHERE address_id = 5
# 2022-05-18 23:03:18,046 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:18,059 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:18,084 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 50.2731305, longitude = 3.1388067 WHERE address_id = 6
# 2022-05-18 23:03:18,085 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:18,096 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:18,121 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 45.2397497, longitude = 5.8192084 WHERE address_id = 7
# 2022-05-18 23:03:18,122 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:18
INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 44.8622853, longitude = -0.6079898 WHERE address_id = 579
# 2022-05-18 23:03:38,314 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,325 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,351 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 45.7760104, longitude = 4.8708645 WHERE address_id = 580
# 2022-05-18 23:03:38,352 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,362 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,388 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 44.78641405, longitude = -0.5624010540934369 WHERE address_id = 581
# 2022-05-18 23:03:38,389 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,398 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,423 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 49.2497005, longitude = 5.9077671 WHERE address_id = 582
# 2022-05-18 23:03:38,423 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,436 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,459 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 45.9192649, longitude = 6.1186343 WHERE address_id = 583
# 2022-05-18 23:03:38,460 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,470 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,496 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 43.6018749, longitude = 3.8710829 WHERE address_id = 584
# 2022-05-18 23:03:38,496 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,507 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,532 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 49.9066312, longitude = 2.2676942 WHERE address_id = 585
# 2022-05-18 23:03:38,533 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,549 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,572 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 43.53601155, longitude = 5.4189244176882365 WHERE address_id = 586
# 2022-05-18 23:03:38,573 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,584 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,615 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 48.8189922, longitude = 2.5177112 WHERE address_id = 587
# 2022-05-18 23:03:38,616 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,626 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,652 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 47.2903784, longitude = 0.7346434 WHERE address_id = 588
# 2022-05-18 23:03:38,652 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,663 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,691 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 48.8753126, longitude = 2.1835603 WHERE address_id = 589
# 2022-05-18 23:03:38,691 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,702 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,727 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 50.6891637, longitude = 2.8815007 WHERE address_id = 590
# 2022-05-18 23:03:38,728 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,738 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,763 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 47.450451, longitude = 5.589989 WHERE address_id = 591
# 2022-05-18 23:03:38,764 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,775 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,800 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 43.1103811, longitude = 3.1012149 WHERE address_id = 592
# 2022-05-18 23:03:38,801 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,812 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,836 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 46.1949743, longitude = -0.9636568 WHERE address_id = 593
# 2022-05-18 23:03:38,836 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,846 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,874 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 43.7064015, longitude = 7.2885294 WHERE address_id = 594
# 2022-05-18 23:03:38,875 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,886 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,911 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 48.6819702, longitude = 6.1974277 WHERE address_id = 596
# 2022-05-18 23:03:38,912 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,923 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,948 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 46.686809, longitude = -1.453672 WHERE address_id = 597
# 2022-05-18 23:03:38,948 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,959 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:38,984 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 49.0363701, longitude = -0.3049697 WHERE address_id = 598
# 2022-05-18 23:03:38,985 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:38,996 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:39,024 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 50.3807865, longitude = 3.0714455 WHERE address_id = 599
# 2022-05-18 23:03:39,025 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:39,036 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:39,063 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 48.587718, longitude = 2.239569 WHERE address_id = 600
# 2022-05-18 23:03:39,063 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:39,073 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:39,098 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 48.868459, longitude = 2.468415 WHERE address_id = 601
# 2022-05-18 23:03:39,098 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:39,109 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:39,136 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 45.74356325, longitude = 4.226839162230233 WHERE address_id = 602
# 2022-05-18 23:03:39,136 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:39,156 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:39,182 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 49.7735463, longitude = 4.7088294 WHERE address_id = 603
# 2022-05-18 23:03:39,182 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:39,193 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:39,222 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 48.9538356, longitude = 2.2929192 WHERE address_id = 604
# 2022-05-18 23:03:39,223 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:39,246 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-18 23:03:39,277 INFO sqlalchemy.engine.Engine UPDATE address SET latitude = 47.4827659, longitude = -1.7472354 WHERE address_id = 605
# 2022-05-18 23:03:39,277 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-18 23:03:39,288 INFO sqlalchemy.engine.Engine COMMIT

# %%
df_final = pd.read_sql("SELECT * FROM address", engine)
df_final
# Out:
# 2022-05-18 23:03:39,376 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2022-05-18 23:03:39,377 INFO sqlalchemy.engine.Engine [cached since 338.3s ago] {'table_schema': 'dataengineer', 'table_name': 'SELECT * FROM address'}
# 2022-05-18 23:03:39,400 INFO sqlalchemy.engine.Engine SELECT * FROM address
# 2022-05-18 23:03:39,400 INFO sqlalchemy.engine.Engine [raw sql] {}
#      address_id                  address                  city postal_code  \
# 0             1     318 CHE DE ROUMAGOUA             LA CIOTAT       13600
# 1             2         19 RUE DES DAMES         SAINTE SAVINE       10300
# 2             3  22 RUE AMIRAL GUEPRATTE            LE CONQUET       29217
# 3             4          6 BD DES ETINES             LE COTEAU       42120
# 4             5      35 AV DU 159EME RIA              BRIANCON        5100
# ..          ...                      ...                   ...         ...
# 557         601              20 RUE COLI             MONTREUIL       93100
# 558         602         6 AV JEAN JAURES                 FEURS       42110
# 559         603     1 RUE HENRI RENAUDIN  CHARLEVILLE-MEZIERES        8000
# 560         604            2 RUE DE LYON      EPINAY SUR SEINE       93800
# 561         605        4 RUE DENIS PAPIN                 BLAIN       44130
#
#      latitude  longitude
# 0     43.2010    5.60580
# 1     48.2909    4.04579
# 2     48.3613   -4.76680
# 3     46.0217    4.09212
# 4     44.8984    6.64363
# ..        ...        ...
# 557   48.8685    2.46842
# 558   45.7436    4.22684
# 559   49.7735    4.70883
# 560   48.9538    2.29292
# 561   47.4828   -1.74724
#
# [562 rows x 6 columns]

# %% [markdown]
# ## SQL Query

# %%
query = """
SELECT c.last_name, c.first_name, a.address, a.city, a.postal_code, a.latitude, a.longitude, COUNT(r.rental_id) AS total_rentals
FROM rental r
JOIN customer c on c.customer_id=r.customer_id
JOIN address a on a.address_id=c.address_id
GROUP BY r.customer_id
ORDER BY total_rentals DESC
LIMIT 1
"""

df_bernardo = pd.read_sql(query, engine)
df_bernardo
# Out:
# 2022-05-18 23:24:55,133 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2022-05-18 23:24:55,134 INFO sqlalchemy.engine.Engine [cached since 1614s ago] {'table_schema': 'dataengineer', 'table_name': '\nSELECT c.last_name, c.first_name, a.address, a.city, a.postal_code, a.latitude, a.longitude, COUNT(r.rental_id) AS total_rentals\nFROM rental r\nJO ... (4 characters truncated) ... ustomer c on c.customer_id=r.customer_id\nJOIN address a on a.address_id=c.address_id\nGROUP BY r.customer_id\nORDER BY total_rentals DESC\nLIMIT 1\n'}
# 2022-05-18 23:24:55,157 INFO sqlalchemy.engine.Engine
# SELECT c.last_name, c.first_name, a.address, a.city, a.postal_code, a.latitude, a.longitude, COUNT(r.rental_id) AS total_rentals
# FROM rental r
# JOIN customer c on c.customer_id=r.customer_id
# JOIN address a on a.address_id=c.address_id
# GROUP BY r.customer_id
# ORDER BY total_rentals DESC
# LIMIT 1
#
# 2022-05-18 23:24:55,158 INFO sqlalchemy.engine.Engine [raw sql] {}
#   last_name first_name             address      city postal_code  latitude  \
# 0      HUNT    ELEANOR  17 IMP DES JARDINS  VALLEIRY       74520   46.1068
#
#    longitude  total_rentals
# 0    5.96634             46
